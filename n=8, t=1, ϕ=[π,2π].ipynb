# %%
from qiskit.quantum_info import Statevector, Operator
from qiskit import QuantumCircuit, Aer, execute
import numpy as np
import math
import matplotlib.pyplot as pl
import random

# %%
n = 8      #no. of qubits
N = 2**n   #dimension of matrix
t = 1      #no. of target states
length = list(range(n))
noi = math.floor(math.sqrt(N/t) * np.pi / 4)   #No of iterations
print("noi = ", noi)

#to set target states
target = np.zeros(t)
count = 0
flag = 0
i = 0
while(True):
    #to generate a random integer for target position
    a = random.randint(0,N-1)
    
    #checking if that number has already been chosen previously as target state
    for j in range(count):
        if(target[j] == a):
            flag = 1  #value is present in the target array
            
    #to store new value in target array
    if(flag == 0):
        #to store in count position of target array
        target[count] = a
        #updating count (position) value
        count += 1
        #checking for further iteration of i loop
        if(count == t):
            break
print("target = ",target)

phi = [a*np.pi/180 for a in range(180,361,15)]
print("phi = ",phi)

phi_m = [a*180/np.pi for a in phi]
print("phi_m = ",phi_m)
print("len(phi) = ",len(phi))

x = [complex(np.cos(a), np.sin(a)) for a in phi]
print("x = ",x)

#array to store coherence values after each suboperation in every grover's iteration
data = np.zeros((len(phi),noi * 4))   #to store coherence values
x_axis = list(range(noi * 4))        #to store iteration number
# Out:
# noi =  12
# target =  [212.]
# phi =  [3.141592653589793, 3.4033920413889422, 3.6651914291880923, 3.9269908169872414, 4.1887902047863905, 4.4505895925855405, 4.71238898038469, 4.97418836818384, 5.235987755982989, 5.497787143782138, 5.759586531581287, 6.021385919380437, 6.283185307179586]
# phi_m =  [180.0, 195.0, 210.0, 225.0, 239.99999999999997, 255.0, 270.0, 285.00000000000006, 300.00000000000006, 315.0, 329.99999999999994, 345.0, 360.0]
# len(phi) =  13
# x =  [(-1+1.2246467991473532e-16j), (-0.9659258262890684-0.25881904510252035j), (-0.8660254037844386-0.5000000000000001j), (-0.7071067811865477-0.7071067811865475j), (-0.5000000000000004-0.8660254037844385j), (-0.25881904510252063-0.9659258262890683j), (-1.8369701987210297e-16-1j), (0.25881904510252113-0.9659258262890682j), (0.5000000000000001-0.8660254037844386j), (0.7071067811865474-0.7071067811865477j), (0.8660254037844384-0.5000000000000004j), (0.9659258262890683-0.2588190451025207j), (1-2.4492935982947064e-16j)]

# %%
def iteration(i,a):
    qc.barrier()
    count = i*4
    qc.append(O_operator,length)
    result = execute(qc, backend).result()
    state = result.get_statevector()
    display("applied O operator to |ψ2⟩", state.draw('latex'))
    density_operator = state.to_operator()
    coherence = 0
    for i in range(N):
        for j in range(N):
            if(i != j):
                coherence += abs(density_operator.data[i,j])
    print("coherence of |ψ2⟩ = ",coherence)
    data[a][count] = coherence

    qc.h(length)
    result = execute(qc, backend).result()
    state = result.get_statevector()
    display("applied Hadamard to all |ψ1⟩", state.draw('latex'))
    density_operator = state.to_operator()
    coherence = 0
    for i in range(N):
        for j in range(N):
            if(i != j):
                coherence += abs(density_operator.data[i,j])
    print("coherence of |ψ1⟩ = ",coherence)
    data[a][count+1] = coherence

    qc.append(P_operator,length)
    result = execute(qc, backend).result()
    state = result.get_statevector()
    display("applied P operator to |ψ4⟩", state.draw('latex'))
    density_operator = state.to_operator()
    coherence = 0
    for i in range(N):
        for j in range(N):
            if(i != j):
                coherence += abs(density_operator.data[i,j])
    print("coherence of |ψ4⟩ = ",coherence)
    data[a][count+2] = coherence

    qc.h(length)
    result = execute(qc, backend).result()
    state = result.get_statevector()
    display("applied Hadamard to all |ψ5⟩", state.draw('latex'))
    density_operator = state.to_operator()
    coherence = 0
    for i in range(N):
        for j in range(N):
            if(i != j):
                coherence += abs(density_operator.data[i,j])
    print("coherence of |ψ5⟩ = ",coherence)
    data[a][count+3] = coherence

for a in range(len(phi)):
    print("======================================== FOR ϕ = ", phi[a]*180/np.pi,"========================================")
    qc = QuantumCircuit(n)
    backend = Aer.get_backend('statevector_simulator')
    result = execute(qc, backend).result()
    state = result.get_statevector()
    display("initialised |ψ0⟩", state.draw('latex'))
    density_operator = state.to_operator()
    #print(density_operator.data)
    coherence = 0
    for i in range(N):
        for j in range(N):
            if(i != j):
                coherence += abs(density_operator.data[i,j])
    print("coherence of |ψ0⟩ = ",coherence)

    qc.h(length)
    result = execute(qc, backend).result()
    state = result.get_statevector()
    display("applied Hadamard to all |ψ1⟩", state.draw('latex'))
    density_operator = state.to_operator()
    #print(density_operator.data)
    coherence = 0
    for i in range(N):
        for j in range(N):
            if(i != j):
                coherence += abs(density_operator.data[i,j])
    print("coherence of |ψ1⟩ = ",coherence)

    #defining generalised O Operator
    count = 0
    choice = a
    O_operator = Operator(np.zeros((N,N)))
    for i in range(N):
        for j in range(N):
            if(i != j):   #off diagonal elements
                O_operator.data[i][j] = 0
            else:    #diagonal elements
                flag = 0
                for k in range(t):
                    if(i == target[k]):
                        O_operator.data[i][j] = x[choice]
                        count += 1
                        flag = 1
                        break
                if(flag == 0):
                    O_operator.data[i][j] = 1            

    #defining P Operator
    P_operator = Operator(np.zeros((N,N)))
    for i in range(N):
        for j in range(N):
            if(i != j):    #off-diagonal elements
                P_operator.data[i][j] = 0
            else:
                if(i==0 & j==0):   #for 1st element only
                    P_operator.data[i][j] = 1
                else:
                    P_operator.data[i][j] = -1

    #sending out for x iterations of grover's operator
    for i in range(noi):
        print("--------",(i+1)," ITERATION--------")
        iteration(i,a)
# Out:
# ======================================== FOR ϕ =  180.0 ========================================
# 'initialised |ψ0⟩'
# $$ |00000000\rangle$$
# coherence of |ψ0⟩ =  0.0
# 'applied Hadamard to all |ψ1⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ1⟩ =  255.00000000000003
# -------- 1  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$\frac{127}{128} |00000000\rangle- \frac{1}{128} |00000001\rangle- \frac{1}{128} |00000010\rangle- \frac{1}{128} |00000011\rangle+\frac{1}{128} |00000100\rangle+\frac{1}{128} |00000101\rangle + \ldots +\frac{1}{128} |11111011\rangle- \frac{1}{128} |11111100\rangle- \frac{1}{128} |11111101\rangle- \frac{1}{128} |11111110\rangle- \frac{1}{128} |11111111\rangle$$
# coherence of |ψ1⟩ =  7.906494140625
# 'applied P operator to |ψ4⟩'
# $$\frac{127}{128} |00000000\rangle+\frac{1}{128} |00000001\rangle+\frac{1}{128} |00000010\rangle+\frac{1}{128} |00000011\rangle- \frac{1}{128} |00000100\rangle- \frac{1}{128} |00000101\rangle + \ldots - \frac{1}{128} |11111011\rangle+\frac{1}{128} |11111100\rangle+\frac{1}{128} |11111101\rangle+\frac{1}{128} |11111110\rangle+\frac{1}{128} |11111111\rangle$$
# coherence of |ψ4⟩ =  7.906494140625
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{63}{1024} |00000000\rangle+\frac{63}{1024} |00000001\rangle+\frac{63}{1024} |00000010\rangle+\frac{63}{1024} |00000011\rangle+\frac{63}{1024} |00000100\rangle+\frac{63}{1024} |00000101\rangle + \ldots +\frac{63}{1024} |11111011\rangle+\frac{63}{1024} |11111100\rangle+\frac{63}{1024} |11111101\rangle+\frac{63}{1024} |11111110\rangle+\frac{63}{1024} |11111111\rangle$$
# coherence of |ψ5⟩ =  251.01562500000003
# -------- 2  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{63}{1024} |00000000\rangle+\frac{63}{1024} |00000001\rangle+\frac{63}{1024} |00000010\rangle+\frac{63}{1024} |00000011\rangle+\frac{63}{1024} |00000100\rangle+\frac{63}{1024} |00000101\rangle + \ldots +\frac{63}{1024} |11111011\rangle+\frac{63}{1024} |11111100\rangle+\frac{63}{1024} |11111101\rangle+\frac{63}{1024} |11111110\rangle+\frac{63}{1024} |11111111\rangle$$
# coherence of |ψ2⟩ =  251.01562500000003
# 'applied Hadamard to all |ψ1⟩'
# $$0.968872070313 |00000000\rangle-0.015502929687 |00000001\rangle-0.015502929688 |00000010\rangle-0.015502929688 |00000011\rangle+0.015502929688 |00000100\rangle+0.015502929688 |00000101\rangle + \ldots +0.015502929688 |11111011\rangle-0.015502929688 |11111100\rangle-0.015502929688 |11111101\rangle-0.015502929688 |11111110\rangle-0.015502929688 |11111111\rangle$$
# coherence of |ψ1⟩ =  23.227256834506992
# 'applied P operator to |ψ4⟩'
# $$0.968872070313 |00000000\rangle+0.015502929687 |00000001\rangle+0.015502929688 |00000010\rangle+0.015502929688 |00000011\rangle-0.015502929688 |00000100\rangle-0.015502929688 |00000101\rangle + \ldots -0.015502929688 |11111011\rangle+0.015502929688 |11111100\rangle+0.015502929688 |11111101\rangle+0.015502929688 |11111110\rangle+0.015502929688 |11111111\rangle$$
# coherence of |ψ4⟩ =  23.227256834506992
# 'applied Hadamard to all |ψ5⟩'
# $$0.059585571289 |00000000\rangle+0.059585571289 |00000001\rangle+0.059585571289 |00000010\rangle+0.059585571289 |00000011\rangle+0.059585571289 |00000100\rangle+0.059585571289 |00000101\rangle + \ldots +0.059585571289 |11111011\rangle+0.059585571289 |11111100\rangle+0.059585571289 |11111101\rangle+0.059585571289 |11111110\rangle+0.059585571289 |11111111\rangle$$
# coherence of |ψ5⟩ =  239.3105506896973
# -------- 3  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$0.059585571289 |00000000\rangle+0.059585571289 |00000001\rangle+0.059585571289 |00000010\rangle+0.059585571289 |00000011\rangle+0.059585571289 |00000100\rangle+0.059585571289 |00000101\rangle + \ldots +0.059585571289 |11111011\rangle+0.059585571289 |11111100\rangle+0.059585571289 |11111101\rangle+0.059585571289 |11111110\rangle+0.059585571289 |11111111\rangle$$
# coherence of |ψ2⟩ =  239.3105506896973
# 'applied Hadamard to all |ψ1⟩'
# $$0.930418014526 |00000000\rangle-0.022951126099 |00000001\rangle-0.022951126099 |00000010\rangle-0.022951126099 |00000011\rangle+0.022951126099 |00000100\rangle+0.022951126099 |00000101\rangle + \ldots +0.022951126099 |11111011\rangle-0.022951126099 |11111100\rangle-0.022951126099 |11111101\rangle-0.022951126099 |11111110\rangle-0.022951126099 |11111111\rangle$$
# coherence of |ψ1⟩ =  45.00848083385792
# 'applied P operator to |ψ4⟩'
# $$0.930418014526 |00000000\rangle+0.022951126099 |00000001\rangle+0.022951126099 |00000010\rangle+0.022951126099 |00000011\rangle-0.022951126099 |00000100\rangle-0.022951126099 |00000101\rangle + \ldots -0.022951126099 |11111011\rangle+0.022951126099 |11111100\rangle+0.022951126099 |11111101\rangle+0.022951126099 |11111110\rangle+0.022951126099 |11111111\rangle$$
# coherence of |ψ4⟩ =  45.00848083385792
# 'applied Hadamard to all |ψ5⟩'
# $$0.056716680527 |00000000\rangle+0.056716680527 |00000001\rangle+0.056716680527 |00000010\rangle+0.056716680527 |00000011\rangle+0.056716680527 |00000100\rangle+0.056716680527 |00000101\rangle + \ldots +0.056716680527 |11111011\rangle+0.056716680527 |11111100\rangle+0.056716680527 |11111101\rangle+0.056716680527 |11111110\rangle+0.056716680527 |11111111\rangle$$
# coherence of |ψ5⟩ =  220.61348652932796
# -------- 4  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$0.056716680527 |00000000\rangle+0.056716680527 |00000001\rangle+0.056716680527 |00000010\rangle+0.056716680527 |00000011\rangle+0.056716680527 |00000100\rangle+0.056716680527 |00000101\rangle + \ldots +0.056716680527 |11111011\rangle+0.056716680527 |11111100\rangle+0.056716680527 |11111101\rangle+0.056716680527 |11111110\rangle+0.056716680527 |11111111\rangle$$
# coherence of |ψ2⟩ =  220.61348652932796
# 'applied Hadamard to all |ψ1⟩'
# $$0.877426177263 |00000000\rangle-0.030040711164 |00000001\rangle-0.030040711164 |00000010\rangle-0.030040711164 |00000011\rangle+0.030040711164 |00000100\rangle+0.030040711164 |00000101\rangle + \ldots +0.030040711164 |11111011\rangle-0.030040711164 |11111100\rangle-0.030040711164 |11111101\rangle-0.030040711164 |11111110\rangle-0.030040711164 |11111111\rangle$$
# coherence of |ψ1⟩ =  71.89415732031671
# 'applied P operator to |ψ4⟩'
# $$0.877426177263 |00000000\rangle+0.030040711164 |00000001\rangle+0.030040711164 |00000010\rangle+0.030040711164 |00000011\rangle-0.030040711164 |00000100\rangle-0.030040711164 |00000101\rangle + \ldots -0.030040711164 |11111011\rangle+0.030040711164 |11111100\rangle+0.030040711164 |11111101\rangle+0.030040711164 |11111110\rangle+0.030040711164 |11111111\rangle$$
# $$\frac{7 \cdot 2^{\frac{73}{85}} \cdot \sqrt[170]{3} \cdot 5^{\frac{137}{170}} \cdot 7^{\frac{81}{170}}}{150 \pi^{\frac{11}{170}}} |00000000\rangle-0.042708282352 |00000001\rangle-0.042708282352 |00000010\rangle-0.042708282352 |00000011\rangle+0.042708282352 |00000100\rangle+0.042708282352 |00000101\rangle + \ldots +0.042708282352 |11111011\rangle-0.042708282352 |11111100\rangle-0.042708282352 |11111101\rangle-0.042708282352 |11111110\rangle-0.042708282352 |11111111\rangle$$
# coherence of |ψ1⟩ =  134.0701253911158
# 'applied P operator to |ψ4⟩'
# $$\frac{7 \cdot 2^{\frac{73}{85}} \cdot \sqrt[170]{3} \cdot 5^{\frac{137}{170}} \cdot 7^{\frac{81}{170}}}{150 \pi^{\frac{11}{170}}} |00000000\rangle+0.042708282352 |00000001\rangle+0.042708282352 |00000010\rangle+0.042708282352 |00000011\rangle-0.042708282352 |00000100\rangle-0.042708282352 |00000101\rangle + \ldots -0.042708282352 |11111011\rangle+0.042708282352 |11111100\rangle+0.042708282352 |11111101\rangle+0.042708282352 |11111110\rangle+0.042708282352 |11111111\rangle$$
# coherence of |ψ4⟩ =  134.0701253911158
# 'applied Hadamard to all |ψ5⟩'
# $$0.043040442572 |00000000\rangle+0.043040442572 |00000001\rangle+0.043040442572 |00000010\rangle+0.043040442572 |00000011\rangle+0.043040442572 |00000100\rangle+0.043040442572 |00000101\rangle + \ldots +0.043040442572 |11111011\rangle+0.043040442572 |11111100\rangle+0.043040442572 |11111101\rangle+0.043040442572 |11111110\rangle+0.043040442572 |11111111\rangle$$
# coherence of |ψ5⟩ =  135.92945094041087
# -------- 7  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$0.043040442572 |00000000\rangle+0.043040442572 |00000001\rangle+0.043040442572 |00000010\rangle+0.043040442572 |00000011\rangle+0.043040442572 |00000100\rangle+0.043040442572 |00000101\rangle + \ldots +0.043040442572 |11111011\rangle+0.043040442572 |11111100\rangle+0.043040442572 |11111101\rangle+0.043040442572 |11111110\rangle+0.043040442572 |11111111\rangle$$
# coherence of |ψ2⟩ =  135.92945094041087
# 'applied Hadamard to all |ψ1⟩'
# $$0.640558743485 |00000000\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000001\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000010\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000011\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000100\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000101\rangle + \ldots +\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111011\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111100\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111101\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111110\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111111\rangle$$
# coherence of |ψ1⟩ =  165.48959865044924
# 'applied P operator to |ψ4⟩'
# $$0.640558743485 |00000000\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000001\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000010\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000011\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000100\rangle- \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |00000101\rangle + \ldots - \frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111011\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111100\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111101\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111110\rangle+\frac{367653125 \cdot 5^{\frac{26}{31}} \cdot 6^{\frac{17}{31}} \cdot 7^{\frac{22}{31}}}{3869835264 \pi^{\frac{119}{31}}} |11111111\rangle$$
# coherence of |ψ4⟩ =  165.48959865044924
# 'applied Hadamard to all |ψ5⟩'
# $$0.037029400363 |00000000\rangle+0.037029400363 |00000001\rangle+0.037029400363 |00000010\rangle+0.037029400363 |00000011\rangle+0.037029400363 |00000100\rangle+0.037029400363 |00000101\rangle + \ldots +0.037029400363 |11111011\rangle+0.037029400363 |11111100\rangle+0.037029400363 |11111101\rangle+0.037029400363 |11111110\rangle+0.037029400363 |11111111\rangle$$
# coherence of |ψ5⟩ =  104.04076898697028
# -------- 8  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$0
# $$0.193668004692 |00000000\rangle-0.061436806492 |00000001\rangle-0.061436806492 |00000010\rangle-0.061436806492 |00000011\rangle+0.061436806492 |00000100\rangle+0.061436806492 |00000101\rangle + \ldots +0.061436806492 |11111011\rangle-0.061436806492 |11111100\rangle-0.061436806492 |11111101\rangle-0.061436806492 |11111110\rangle-0.061436806492 |11111111\rangle$$
# coherence of |ψ1⟩ =  250.54130210644297
# 'applied P operator to |ψ4⟩'
# $$0.193668004692 |00000000\rangle+0.061436806492 |00000001\rangle+0.061436806492 |00000010\rangle+0.061436806492 |00000011\rangle-0.061436806492 |00000100\rangle-0.061436806492 |00000101\rangle + \ldots -0.061436806492 |11111011\rangle+0.061436806492 |11111100\rangle+0.061436806492 |11111101\rangle+0.061436806492 |11111110\rangle+0.061436806492 |11111111\rangle$$
# coherence of |ψ4⟩ =  250.54130210644297
# 'applied Hadamard to all |ψ5⟩'
# $$0.008264449887 |00000000\rangle+0.008264449887 |00000001\rangle+0.008264449887 |00000010\rangle+0.008264449887 |00000011\rangle+0.008264449887 |00000100\rangle+0.008264449887 |00000101\rangle + \ldots +0.008264449887 |11111011\rangle+0.008264449887 |11111100\rangle+0.008264449887 |11111101\rangle+0.008264449887 |11111110\rangle+0.008264449887 |11111111\rangle$$
# coherence of |ψ5⟩ =  8.601867786560419
# -------- 12  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$0.008264449887 |00000000\rangle+0.008264449887 |00000001\rangle+0.008264449887 |00000010\rangle+0.008264449887 |00000011\rangle+0.008264449887 |00000100\rangle+0.008264449887 |00000101\rangle + \ldots +0.008264449887 |11111011\rangle+0.008264449887 |11111100\rangle+0.008264449887 |11111101\rangle+0.008264449887 |11111110\rangle+0.008264449887 |11111111\rangle$$
# coherence of |ψ2⟩ =  8.601867786560419
# 'applied Hadamard to all |ψ1⟩'
# $$0.069761335471 |00000000\rangle-0.062469862728 |00000001\rangle-0.062469862728 |00000010\rangle-0.062469862728 |00000011\rangle+0.062469862728 |00000100\rangle+0.062469862728 |00000101\rangle + \ldots +0.062469862728 |11111011\rangle-0.062469862728 |11111100\rangle-0.062469862728 |11111101\rangle-0.062469862728 |11111110\rangle-0.062469862728 |11111111\rangle$$
# coherence of |ψ1⟩ =  254.98644277810365
# 'applied P operator to |ψ4⟩'
# $$0.069761335471 |00000000\rangle+0.062469862728 |00000001\rangle+0.062469862728 |00000010\rangle+0.062469862728 |00000011\rangle-0.062469862728 |00000100\rangle-0.062469862728 |00000101\rangle + \ldots -0.062469862728 |11111011\rangle+0.062469862728 |11111100\rangle+0.062469862728 |11111101\rangle+0.062469862728 |11111110\rangle+0.062469862728 |11111111\rangle$$
# coherence of |ψ4⟩ =  254.98644277810365
# 'applied Hadamard to all |ψ5⟩'
# $$0.000455717046 |00000000\rangle+0.000455717046 |00000001\rangle+0.000455717046 |00000010\rangle+0.000455717046 |00000011\rangle+0.000455717046 |00000100\rangle+0.000455717046 |00000101\rangle + \ldots +0.000455717046 |11111011\rangle+0.000455717046 |11111100\rangle+0.000455717046 |11111101\rangle+0.000455717046 |11111110\rangle+0.000455717046 |11111111\rangle$$
# coherence of |ψ5⟩ =  0.24586084522685947
# ======================================== FOR ϕ =  195.0 ========================================
# 'initialised |ψ0⟩'
# $$ |00000000\rangle$$
# coherence of |ψ0⟩ =  0.0
# 'applied Hadamard to all |ψ1⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ1⟩ =  255.00000000000003
# -------- 1  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$(0.992320602241 - 0.001011011895 i) |00000000\rangle+ (-0.007679397759 - 0.001011011895 i) |00000001\rangle+ (-0.007679397759 - 0.001011011895 i) |00000010\rangle+ (-0.007679397759 - 0.001011011895 i) |00000011\rangle+ (0.007679397759 + 0.001011011895 i) |00000100\rangle+ (0.007679397759 + 0.001011011895 i) |00000101\rangle + \ldots + (0.007679397759 + 0.001011011895 i) |11111011\rangle+ (-0.007679397759 - 0.001011011895 i) |11111100\rangle+ (-0.007679397759 - 0.001011011895 i) |11111101\rangle+ (-0.007679397759 - 0.001011011895 i) |11111110\rangle+ (-0.007679397759 - 0.001011011895 i) |11111111\rangle$$
# coherence of |ψ1⟩ =  7.8058495769147225
# 'applied P operator to |ψ4⟩'
# $$(0.992320602241 - 0.001011011895 i) |00000000\rangle+ (0.007679397759 + 0.001011011895 i) |00000001\rangle+ (0.007679397759 + 0.001011011895 i) |00000010\rangle+ (0.007679397759 + 0.001011011895 i) |00000011\rangle+ (-0.007679397759 - 0.001011011895 i) |00000100\rangle+ (-0.007679397759 - 0.001011011895 i) |00000101\rangle + \ldots + (-0.007679397759 - 0.001011011895 i) |11111011\rangle+ (0.007679397759 + 0.001011011895 i) |11111100\rangle+ (0.007679397759 + 0.001011011895 i) |11111101\rangle+ (0.007679397759 + 0.001011011895 i) |11111110\rangle+ (0.007679397759 + 0.001011011895 i) |11111111\rangle$$
# coherence of |ψ4⟩ =  7.8058495769147225
# 'applied Hadamard to all |ψ5⟩'
# $$(0.06154007528 - 0.000126376487 i) |00000000\rangle+ (0.06154007528 - 0.000126376487 i) |00000001\rangle+ (0.06154007528 - 0.000126376487 i) |00000010\rangle+ (0.06154007528 - 0.000126376487 i) |00000011\rangle+ (0.06154007528 - 0.000126376487 i) |00000100\rangle+ (0.06154007528 - 0.000126376487 i) |00000101\rangle + \ldots + (0.06154007528 - 0.000126376487 i) |11111011\rangle+ (0.06154007528 - 0.000126376487 i) |11111100\rangle+ (0.06154007528 - 0.000126376487 i) |11111101\rangle+ (0.06154007528 - 0.000126376487 i) |11111110\rangle+ (0.06154007528 - 0.000126376487 i) |11111111\rangle$$
# coherence of |ψ5⟩ =  251.10643309444606
# -------- 2  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$(0.06154007528 - 0.000126376487 i) |00000000\rangle+ (0.06154007528 - 0.000126376487 i) |00000001\rangle+ (0.06154007528 - 0.000126376487 i) |00000010\rangle+ (0.06154007528 - 0.000126376487 i) |00000011\rangle+ (0.06154007528 - 0.000126376487 i) |00000100\rangle+ (0.06154007528 - 0.000126376487 i) |00000101\rangle + \ldots + (0.06154007528 - 0.000126376487 i) |11111011\rangle+ (0.06154007528 - 0.000126376487 i) |11111100\rangle+ (0.06154007528 - 0.000126376487 i) |11111101\rangle+ (0.06154007528 - 0.000126376487 i) |11111110\rangle+ (0.06154007528 - 0.000126376487 i) |11111111\rangle$$
# coherence of |ψ2⟩ =  240.05997643246434
# 'applied Hadamard to all |ψ1⟩'
# $$(0.934659505648 - 0.018419228371 i) |00000000\rangle+ (-0.020542588351 - 0.008509018701 i) |00000001\rangle+ (-0.020542588351 - 0.008509018701 i) |00000010\rangle+ (-0.020542588351 - 0.008509018701 i) |00000011\rangle+ (0.020542588351 + 0.008509018701 i) |00000100\rangle+ (0.020542588351 + 0.008509018701 i) |00000101\rangle + \ldots + (0.020542588351 + 0.008509018701 i) |11111011\rangle+ (-0.020542588351 - 0.008509018701 i) |11111100\rangle+ (-0.020542588351 - 0.008509018701 i) |11111101\rangle+ (-0.020542588351 - 0.008509018701 i) |11111110\rangle+ (-0.020542588351 - 0.008509018701 i) |11111111\rangle$$
# coherence of |ψ1⟩ =  42.623396500942505
# 'applied P operator to |ψ4⟩'
# $$(0.934659505648 - 0.018419228371 i) |00000000\rangle+ (0.020542588351 + 0.008509018701 i) |00000001\rangle+ (0.020542588351 + 0.008509018701 i) |00000010\rangle+ (0.020542588351 + 0.008509018701 i) |00000011\rangle+ (-0.020542588351 - 0.008509018701 i) |00000100\rangle+ (-0.020542588351 - 0.008509018701 i) |00000101\rangle + \ldots + (-0.020542588351 - 0.008509018701 i) |11111011\rangle+ (0.020542588351 + 0.008509018701 i) |11111100\rangle+ (0.020542588351 + 0.008509018701 i) |11111101\rangle+ (0.020542588351 + 0.008509018701 i) |11111110\rangle+ (0.020542588351 + 0.008509018701 i) |11111111\rangle$$
# coherence of |ψ4⟩ =  42.623396500942505
# 'applied Hadamard to all |ψ5⟩'
# $$(0.057132307331 - 0.001683015442 i) |00000000\rangle+ (0.057132307331 - 0.001683015442 i) |00000001\rangle+ (0.057132307331 - 0.001683015442 i) |00000010\rangle+ (0.057132307331 - 0.001683015442 i) |00000011\rangle+ (0.057132307331 - 0.001683015442 i) |00000100\rangle+ (0.057132307331 - 0.001683015442 i) |00000101\rangle + \ldots + (0.057132307331 - 0.001683015442 i) |11111011\rangle+ (0.057132307331 - 0.001683015442 i) |11111100\rangle+ (0.057132307331 - 0.001683015442 i) |11111101\rangle+ (0.057132307331 - 0.001683015442 i) |11111110\rangle+ (0.057132307331 - 0.001683015442 i) |11111111\rangle$$
# coherence of |ψ5⟩ =  223.5092122704776
# -------- 4  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$(0.057132307331 - 0.001683015442 i) |00000000\rangle+ (0.057132307331 - 0.001683015442 i) |00000001\rangle+ (0.057132307331 - 0.001683015442 i) |00000010\rangle+ (0.057132307331 - 0.001683015442 i) |00000011\rangle+ (0.057132307331 - 0.001683015442 i) |00000100\rangle+ (0.057132307331 - 0.001683015442 i) |00000101\rangle + \ldots + (0.057132307331 - 0.001683015442 i) |11111011\rangle+ (0.057132307331 - 0.001683015442 i) |11111100\rangle+ (0.057132307331 - 0.001683015442 i) |11111101\rangle+ (0.057132307331 - 0.001683015442 i) |11111110\rangle+ (0.057132307331 - 0.001683015442 i) |11111111\rangle$$
# coherence of |ψ2⟩ =  223.5092122704776
# 'applied Hadamard to all |ψ1⟩'
# $$(0.889429504581 - 0.041181531449 i) |00000000\rangle+ (-0.024687412716 - 0.014253284377 i) |00000001\rangle+ (-0.024687412716 - 0.014253284377 i) |00000010\rangle+ (-0.024687412716 - 0.014253284377 i) |00000011\rangle+ (0.024687412716 + 0.014253284377 i) |00000100\rangle+ (0.024687412716 + 0.014253284377 i) |00000101\rangle + \ldots + (0.024687412716 + 0.014253284377 i) |11111011\rangle+ (-0.024687412716 - 0.014253284377 i) |11111100\rangle+ (-0.024687412716 - 0.014253284377 i) |11111101\rangle+ (-0.024687412716 - 0.014253284377 i) |11111110\rangle+ (-0.024687412716 - 0.014253284377 i) |11111111\rangle$$
# coherence of |ψ1⟩ =  65.57837697817169
# 'applied P operator to |ψ4⟩'
# $$(0.889429504581 - 0.041181531449 i) |00000000\rangle+ (0.024687412716 + 0.014253284377 i) |00000001\rangle+ (0.024687412716 + 0.014253284377 i) |00000010\rangle+ (0.024687412716 + 0.014253284377 i) |00000011\rangle+ (-0.024687412716 - 0.014253284377 i) |00000100\rangle+ (-0.024687412716 - 0.014253284377 i) |00000101\rangle + \ldots + (-0.024687412716 - 0.014253284377 i) |11111011\rangle+ (0.024687412716 + 0.014253284377 i) |11111100\rangle+ (0.024687412716 + 0.014253284377 i) |11111101\rangle+ (0.024687412716 + 0.014253284377 i) |11111110\rangle+ (0.024687412716 + 0.014253284377 i) |11111111\rangle$$
# coherence of |ψ4⟩ =  65.57837697817169
# 'applied Hadamard to all |ψ5⟩'
# $$(0.054046380742 - 0.003464675989 i) |00000000\rangle+ (0.054046380742 - 0.003464675989 i) |00000001\rangle+ (0.054046380742 - 0.003464675989 i) |00000010\rangle+ (0.054046380742 - 0.003464675989 i) |00000011\rangle+ (0.054046380742 - 0.003464675989 i) |00000100\rangle+ (0.054046380742 - 0.003464675989 i) |00000101\rangle + \ldots + (0.054046380742 - 0.003464675989 i) |11111011\rangle+ (0.054046380742 - 0.003464675989 i) |11111100\rangle+ (0.054046380742 - 0.003464675989 i) |11111101\rangle+ (0.054046380742 - 0.003464675989 i) |11111110\rangle+ (0.054046380742 - 0.003464675989 i) |11111111\rangle$$
# coherence of |ψ5⟩ =  203.83887590937405
# -------- 5  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$(0.054046380742 - 0.003464675989 i) |00000000\rangle+ (0.054046380742 - 0.003464675989 i) |00000001\rangle+ (0.054046380742 - 0.003464675989 i) |00000010\rangle+ (0.054046380742 - 0.003464675989 i) |00000011\rangle+ (0.054046380742 - 0.003464675989 i) |00000100\rangle+ (0.054046380742 - 0.003464675989 i) |00000101\rangle + \ldots + (0.054046380742 - 0.003464675989 i) |11111011\rangle+ (0.054046380742 - 0.003464675989 i) |11111100\rangle+ (0.054046380742 - 0.003464675989 i) |11111101\rangle+ (0.054046380742 - 0.003464675989 i) |11111110\rangle+ (0.054046380742 - 0.003464675989 i) |11111111\rangle$$
# coherence of |ψ2⟩ =  203.83887590937405
# 'applied Hadamard to all |ψ1⟩'
# $$(0.83788816005 - 0.076040562441 i) |00000000\rangle+ (-0.026853931815 - 0.020605746615 i) |00000001\rangle+ (-0.026853931815 - 0.020605746615 i) |00000010\rangle+ (-0.026853931815 - 0.020605746615 i) |00000011\rangle+ (0.026853931815 + 0.020605746615 i) |00000100\rangle+ (0.026853931815 + 0.020605746615 i) |00000101\rangle + \ldots + (0.026853931815 + 0.020605746615 i) |11111011\rangle+ (-0.026853931815 - 0.020605746615 i) |11111100\rangle+ (-0.026853931815 - 0.020605746615 i) |11111101\rangle+ (-0.026853931815 - 0.020605746615 i) |11111110\rangle+ (-0.026853931815 - 0.020605746615 i) |11111111\rangle$$
# coherence of |ψ1⟩ =  88.73270443987612
# 'applied P operator to |ψ4⟩'
# $$(0.83788816005 - 0.076040562441 i) |00000000\rangle+ (0.026853931815 + 0.020605746615 i) |00000001\rangle+ (0.026853931815 + 0.020605746615 i) |00000010\rangle+ (0.026853931815 + 0.020605746615 i) |00000011\rangle+ (-0.026853931815 - 0.020605746615 i) |00000100\rangle+ (-0.026853931815 - 0.020605746615 i) |00000101\rangle + \ldots + (-0.026853931815 - 0.020605746615 i) |11111011\rangle+ (0.026853931815 + 0.020605746615 i) |11111100\rangle+ (0.026853931815 + 0.020605746615 i) |11111101\rangle+ (0.026853931815 + 0.020605746615 i) |11111110\rangle+ (0.026853931815 + 0.020605746615 i) |11111111\rangle$$
# coherence of |ψ4⟩ =  88.73270443987612
# 'applied Hadamard to all |ψ5⟩'
# $$(0.050689639265 - 0.006040394316 i) |00000000\rangle+ (0.050689639265 - 0.006040394316 i) |00000001\rangle+ (0.050689639265 - 0.006040394316 i) |00000010\rangle+ (0.050689639265 - 0.006040394316 i) |00000011\rangle+ (0.050689639265 - 0.006040394316 i) |00000100\rangle+ (0.050689639265 - 0.006040394316 i) |00000101\rangle + \ldots + (0.050689639265 - 0.006040394316 i) |11111011\rangle+ (0.050689639265 - 0.006040394316 i) |11111100\rangle+ (0.050689639265 - 0.006040394316 i) |11111101\rangle+ (0.050689639265 - 0.006040394316 i) |11111110\rangle+ (0.050689639265 - 0.006040394316 i) |11111111\rangle$$
# coherence of |ψ5⟩ =  183.86543605560857
# -------- 6  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$(0.050689639265 - 0.006040394316 i) |00000000\rangle+ (0.050689639265 - 0.006040394316 i) |00000001\rangle+ (0.050689639265 - 0.006040394316 i) |00000010\rangle+ (0.050689639265 - 0.006040394316 i) |00000011\rangle+ (0.050689639265 - 0.006040394316 i) |00000100\rangle+ (0.050689639265 - 0.006040394316 i) |00000101\rangle + \ldots + (0.050689639265 - 0.006040394316 i) |11111011\rangle+ (0.050689639265 - 0.006040394316 i) |11111100\rangle+ (0.050689639265 - 0.006040394316 i) |11111101\rangle+ (0.050689639265 - 0.006040394316 i) |11111110\rangle+ (0.050689639265 - 0.006040394316 i) |11111111\rangle$$
# coherence of |ψ2⟩ =  183.86543605560857
# 'applied Hadamard to all |ψ1⟩'
# $$(0.784102516617 - 0.123578020674 i) |00000000\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000001\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000010\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000011\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000100\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000101\rangle + \ldots + (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111011\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111100\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111101\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111110\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111111\rangle$$
# coherence of |ψ1⟩ =  109.37634952100794
# 'applied P operator to |ψ4⟩'
# $$(0.784102516617 - 0.123578020674 i) |00000000\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000001\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000010\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000011\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000100\rangle+ (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |00000101\rangle + \ldots + (- \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} - \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111011\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111100\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111101\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111110\rangle+ (\frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}}}{150 \pi^{\frac{622}{427}}} + \frac{2^{\frac{258}{427}} \cdot 3^{\frac{28}{61}} \cdot 5^{\frac{285}{427}} \cdot 7^{\frac{234}{427}} i}{150 \pi^{\frac{622}{427}}}) |11111111\rangle$$
# coherence of |ψ4⟩ =  109.37634952100794
# 'applied Hadamard to all |ψ5⟩'
# $$(0.047323175312 - 0.009406858268 i) |00000000\rangle+ (0.047323175312 - 0.009406858268 i) |00000001\rangle+ (0.047323175312 - 0.009406858268 i) |00000010\rangle+ (0.047323175312 - 0.009406858268 i) |00000011\rangle+ (0.047323175312 - 0.009406858268 i) |00000100\rangle+ (0.047323175312 - 0.009406858268 i) |00000101\rangle + \ldots + (0.047323175312 - 0.009406858268 i) |11111011\rangle+ (0.047323175312 - 0.009406858268 i) |11111100\rangle+ (0.047323175312 - 0.009406858268 i) |11111101\rangle+ (0.047323175312 - 0.009406858268 i) |11111110\rangle+ (0.047323175312 - 0.009406858268 i) |11111111\rangle$$
# coherence of |ψ5⟩ =  166.46896189013592
# -------- 7  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$(0.047323175312 - 0.009406858268 i) |00000000\rangle+ (0.047323175312 - 0.009406858268 i) |00000001\rangle+ (0.047323175312 - 0.009406858268 i) |00000010\rangle+ (0.047323175312 - 0.009406858268 i) |00000011\rangle+ (0.047323175312 - 0.009406858268 i) |00000100\rangle+ (0.047323175312 - 0.009406858268 i) |00000101\rangle + \ldots + (0.047323175312 - 0.009406858268 i) |11111011\rangle+ (0.047323175312 - 0.009406858268 i) |11111100\rangle+ (0.047323175312 - 0.009406858268 i) |11111101\rangle+ (0.047323175312 - 0.009406858268 i) |11111110\rangle+ (0.047323175312 - 0.009406858268 i) |11111111\rangle$$
# coherence of |ψ2⟩ =  166.46896189013592
# 'applied Hadamard to all |ψ1⟩'
# $$(0.732160426173 - 0.183103892564 i) |00000000\rangle+ (-0.025010378827 - 0.032594160271 i) |00000001\rangle+ (-0.025010378827 - 0.032594160271 i) |00000010\rangle+ (-0.025010378827 - 0.032594160271 i) |00000011\rangle+ (0.025010378827 + 0.032594160271 i) |00000100\rangle+ (0.025010378827 + 0.032594160271 i) |00000101\rangle + \ldots + (0.025010378827 + 0.032594160271 i) |11111011\rangle+ (-0.025010378827 - 0.032594160271 i) |11111100\rangle+ (-0.025010378827 - 0.032594160271 i) |11111101\rangle+ (-0.025010378827 - 0.032594160271 i) |11111110\rangle+ (-0.025010378827 - 0.032594160271 i) |11111111\rangle$$
# $$(0.062486812553 - 0.00083559957 i) |00000000\rangle+ (0.062486812553 - 0.00083559957 i) |00000001\rangle+ (0.062486812553 - 0.00083559957 i) |00000010\rangle+ (0.062486812553 - 0.00083559957 i) |00000011\rangle+ (0.062486812553 - 0.00083559957 i) |00000100\rangle+ (0.062486812553 - 0.00083559957 i) |00000101\rangle + \ldots + (0.062486812553 - 0.00083559957 i) |11111011\rangle+ (0.062486812553 - 0.00083559957 i) |11111100\rangle+ (0.062486812553 - 0.00083559957 i) |11111101\rangle+ (0.062486812553 - 0.00083559957 i) |11111110\rangle+ (0.062486812553 - 0.00083559957 i) |11111111\rangle$$
# coherence of |ψ5⟩ =  254.99906338140235
# ======================================== FOR ϕ =  360.0 ========================================
# 'initialised |ψ0⟩'
# $$ |00000000\rangle$$
# coherence of |ψ0⟩ =  0.0
# 'applied Hadamard to all |ψ1⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ1⟩ =  255.00000000000003
# -------- 1  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  1.5949894988535384e-15
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  1.5949894988535384e-15
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 2  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  5.468646926129539e-16
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  5.468646926129539e-16
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 3  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  1.5949894988535386e-15
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  1.5949894988535386e-15
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 4  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  5.46864692612957e-16
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  5.46864692612957e-16
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 5  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  1.5949894988535406e-15
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  1.5949894988535406e-15
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 6  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  5.468646926129632e-16
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  5.468646926129632e-16
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 7  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  1.5949894988535427e-15
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  1.5949894988535427e-15
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 8  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  5.468646926129705e-16
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  5.468646926129705e-16
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 9  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  1.5949894988535494e-15
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  1.5949894988535494e-15
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 10  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  5.468646926129785e-16
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  5.468646926129785e-16
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 11  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  1.5949894988535496e-15
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  1.5949894988535496e-15
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003
# -------- 12  ITERATION--------
# 'applied O operator to |ψ2⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ2⟩ =  255.00000000000003
# 'applied Hadamard to all |ψ1⟩'
# $$ |00000000\rangle$$
# coherence of |ψ1⟩ =  5.468646926129908e-16
# 'applied P operator to |ψ4⟩'
# $$ |00000000\rangle$$
# coherence of |ψ4⟩ =  5.468646926129908e-16
# 'applied Hadamard to all |ψ5⟩'
# $$\frac{1}{16} |00000000\rangle+\frac{1}{16} |00000001\rangle+\frac{1}{16} |00000010\rangle+\frac{1}{16} |00000011\rangle+\frac{1}{16} |00000100\rangle+\frac{1}{16} |00000101\rangle + \ldots +\frac{1}{16} |11111011\rangle+\frac{1}{16} |11111100\rangle+\frac{1}{16} |11111101\rangle+\frac{1}{16} |11111110\rangle+\frac{1}{16} |11111111\rangle$$
# coherence of |ψ5⟩ =  255.00000000000003

# %%
data_N = [a/N for a in data]
xa = [a/4 for a in x_axis]

a = len(phi)//3
b = len(phi)//a
fig, axs = pl.subplots(a,b, figsize=(10,10))
count = 0
for i in range(a):
    for j in range(b):
        axs[i,j].scatter(xa[::4], data_N[count][::4], color='red', label='O')
        axs[i,j].scatter(xa[1::4], data_N[count][1::4], color='blue', marker='<', label='H')
        axs[i,j].scatter(xa[2::4], data_N[count][2::4], color='black', marker='>', label='P')
        axs[i,j].scatter(xa[3::4], data_N[count][3::4], color='green', marker='d', label='H')
        axs[i,j].plot(xa, data_N[count])
        axs[i,j].set_title("φ = " + str(phi[count]*180/np.pi))
        count += 1
        pl.subplots_adjust(top=1, right=1.5)
pl.show()
